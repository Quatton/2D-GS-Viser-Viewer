# %%
# !python viewer.py 2d_gaussian_splatting/output/2025-04-19/scan105/point_cloud/iteration_7000/point_cloud.ply
# Out:
# [INFO] ply path loaded from: 2d_gaussian_splatting/output/2025-04-19/scan105/point_cloud/iteration_7000/point_cloud.ply
# [INFO] number of points: 135755
# ╭──────────────── viser ────────────────╮
# │             ╷                         │
# │   HTTP      │ http://localhost:8080   │
# │   Websocket │ ws://localhost:8080     │
# │             ╵                         │
# ╰───────────────────────────────────────╯
# (viser) Connection opened (0, 1 total), 83 persistent messages
# (viser) Connection opened (1, 2 total), 83 persistent messages
# Traceback (most recent call last):
#   File "/home/qtn/Documents/GitHub/2d-gaussian-splatting/2D-GS-Viser-Viewer/viewer.py", line 550, in <module>
#     viewer.start()
#   File "/home/qtn/Documents/GitHub/2d-gaussian-splatting/2D-GS-Viser-Viewer/viewer.py", line 245, in start
#     time.sleep(999)
# KeyboardInterrupt
# ^C

# %%
# !python viewer.py 2d_gaussian_splatting/2DGS_data/dtu_results/mesh/scan105.ply
# Out:
# [INFO] ply path loaded from: 2d_gaussian_splatting/2DGS_data/dtu_results/mesh/scan105.ply
# Traceback (most recent call last):
#   File "/home/qtn/Documents/GitHub/2d-gaussian-splatting/2D-GS-Viser-Viewer/viewer.py", line 549, in <module>
#     viewer = Viewer(args, **viewer_init_args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/qtn/Documents/GitHub/2d-gaussian-splatting/2D-GS-Viser-Viewer/viewer.py", line 88, in __init__
#     self._init_models(iterations)
#   File "/home/qtn/Documents/GitHub/2d-gaussian-splatting/2D-GS-Viser-Viewer/viewer.py", line 103, in _init_models
#     self.gaussian_model.load_ply(self.ply_path)
#   File "/home/qtn/Documents/GitHub/2d-gaussian-splatting/2D-GS-Viser-Viewer/2d_gaussian_splatting/scene/gaussian_model.py", line 220, in load_ply
#     opacities = np.asarray(plydata.elements[0]["opacity"])[..., np.newaxis]
#                            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^
# ...
